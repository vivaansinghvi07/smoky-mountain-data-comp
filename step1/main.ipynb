# %% [markdown]
# **Question**: Is it possible to use optical character recognition (OCR) or machine learning techniques to “Read” the label on each tag and generate a spreadsheet contains the treatment, block, row, position, and genotype? Doing this would dramatically simplify data collection, as this information is usually collected manually.

# %%
import os
import re
import cv2
import random
import imutils
import numpy as np
import pandas as pd
from typing import Any
from pathlib import Path
from openpyxl import Workbook
from paddleocr import PaddleOCR
from matplotlib import pyplot as plt
from IPython.display import clear_output
from tensorflow.keras.preprocessing import image as tfimage

# %%
# get smoky-mountain-data-comp folder
HOME_DIR = str(Path().cwd().parent)

#  type decls
cv2.Image = np.ndarray
cv2.Contour = np.ndarray

# shows an image on ipynb
def imshow(img: cv2.Image) -> None:
    plt.axis('off')
    plt.grid(False)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# grayscale an image (easy function call)
def grayscale(img: cv2.Image) -> cv2.Image:
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# Defines image processor to center the text in the image

# %%
# find threshold for the image
def process_image(img: cv2.Image, strength: int = 1) -> cv2.Image:
    gray = grayscale(img)
    blur = tfimage.img_to_array(cv2.medianBlur(gray, 5), dtype='uint8')
    thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 21, strength)
    return thresh

# test the process_image function
def test(filename: str) -> None:
    img = cv2.imread(filename)
    imshow(img)
    imshow(process_image(img, strength=1))
    imshow(process_image(img, strength=-2))

test(f"{HOME_DIR}/dataset/49D625B3-2C33-44EE-BDE7-4A5A88E5E66B.jpg")

# %%
def disp_pipeline(step: int, mat: cv2.Mat) -> None:
    imshow(mat)
    cv2.imwrite(f"pipeline/{step}.png", mat)

img = cv2.imread(f"{HOME_DIR}/dataset/49D625B3-2C33-44EE-BDE7-4A5A88E5E66B.jpg")
disp_pipeline(1, img)
disp_pipeline(2, process_image(img, strength=-2))
disp_pipeline(3, imutils.rotate(img, -45))
disp_pipeline(4, imutils.rotate(process_image(img, strength=-2), -45))

# %% [markdown]
# Read and obtain text from the images

# %%
PADDLE_OCR = PaddleOCR(use_angle_cls=True, lang='en', show_log=False, rotation=True)
SHOW_IMAGE = "False"    # conditions for showing image (is eval'ed)
ROTATION_ANGLE = -45    # angle to rotate by when reading fails
MIN_LEN = 8             # length of text to be considered valid
DATASET_PATH = f"{HOME_DIR}/dataset" 

# obtains just the text from an OCR model
def get_text(text: Any, mode: str) -> str:
    if mode == "paddle":
        output = ""
        if text == [[]]:
            return None
        s = sorted(text[0], key=lambda x: x[0][0])
        if re.search(r"[BR]\d", s[-1][1][0]) is not None:
            s = reversed(s)
        for item in s:
            output += item[1][0]
        if len(output) < MIN_LEN:
            return None
        return output
    
ocr_texts = []

# try many different image configurations to get some text
for filename in os.listdir(DATASET_PATH):
    image = cv2.imread(f"{DATASET_PATH}/{filename}")
    img_was_rotated = False
    if (text:=get_text(PADDLE_OCR.ocr(image), mode="paddle")) is None:          # try with normal
        bw_image = process_image(image, strength=-2)
        if (text:=get_text(PADDLE_OCR.ocr(bw_image), mode="paddle")) is None:   # try with processed
            rt_image = imutils.rotate(image, ROTATION_ANGLE)
            img_was_rotated = True
            if (text:=get_text(PADDLE_OCR.ocr(rt_image), mode="paddle")) is None:   # try rotated
                bw_rt_image = process_image(rt_image, strength=-2)
                text = get_text(PADDLE_OCR.ocr(bw_rt_image), mode="paddle")         # try rotated & processed
    
    # add to texts and show image
    ocr_texts.append((filename, text))
    if eval(SHOW_IMAGE):
        imshow(image)

# calculate reading percentage
print(f"Texts not detected: \033[31m{sum(map(lambda x: x[1] is None, ocr_texts))/len(ocr_texts):.2%}\033[0m")
# Out:
# Texts not detected: 9.27%

# %%
df_list = []
for (filename, text) in ocr_texts:

    df_row = {
        'filename': filename,
        'treatment': None,
        'block': None,
        'row': None,
        'position': None,
        'genotype': None
    }
    df_list.append(df_row)

    if text is None:
        continue

    text = text.replace(' ', '_').upper()

    # get block, row, position
    if (block:=re.search(r"B\d+", text)) is not None:
        df_row['block'] = int(block.group().replace('B', ''))
    if (position:=re.search(r"P\d+", text)) is not None:
        df_row['position'] = int(position.group().replace('P', ''))
    if (row:=re.search(r"R\d+", text)) is not None:
        df_row['row'] = int(row.group().replace('R', ''))

    # get treatment
    if (u:=text[0].upper()) in ['C', 'D']:
        df_row['treatment'] = text[0]

    # get genotype
    if (genotype:=re.search(r"[A-Z]{2,}(-\d+)+(_\d+)*(_[A-Z]+)?", text)) is not None:
        genotype = genotype.group()
        if '*' in text:
            genotype = f"**{genotype}**,core"
        df_row['genotype'] = genotype

df = pd.DataFrame(df_list)
for col in ['position', 'block', 'row']:
    df[col] = pd.to_numeric(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   filename   1672 non-null   object
#  1   treatment  1098 non-null   object
#  2   block      1306 non-null   float64
#  3   row        1388 non-null   float64
#  4   position   1414 non-null   float64
#  5   genotype   1431 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 78.5+ KB

# %%
df.tail()
# Out:
#                                       filename treatment  block   row  \
# 1667  91F395A8-E156-416C-84E8-A2880F067945.jpg      None    NaN   NaN
# 1668  18E8E0DC-35EE-4C34-839A-71E0E6D7F3AD.jpg         C    1.0  12.0
# 1669  DB2D48CC-17CD-4A96-BC52-CFFC5879641B.jpg         C    2.0   5.0
# 1670  2258AE77-D53C-446F-8DAD-0E948854EBDC.jpg         C    2.0  42.0
# 1671  5FCC7048-CC04-40DA-B3DB-F6404CA41931.jpg         C    2.0  38.0
#
#       position             genotype
# 1667       NaN                 None
# 1668      27.0           GW-6962_WP
# 1669      49.0           GW-9784_LM
# 1670      43.0  **GW-4579_WP**,core
# 1671      31.0          BESC-217_LM

# %%
EXAMPLE_DATA = pd.DataFrame({
    'filename': ['example1.png', 'example2.png'],
    'treatment': ['C', 'D'],
    'block': ['1', '2'],
    'row': ['54', '23'],
    'position': ['12', '10'],
    'genotype': ['BESC-4590_LM', 'BESC-4230_LM']
})

def make_sheet(data: pd.DataFrame, excel_file: str) -> None:
    wb = Workbook()
    worksheet = wb.active
    
    # For writing the Header Rows on Excel
    headers = [*data.keys()]
    worksheet.append(headers)

    # For writing the data rows for each image in the dataset
    for i in range(len(data)):
        row = [data[header][i] for header in headers]
        worksheet.append(row)

    wb.save(excel_file)
        
make_sheet(df, 'data.xlsx')

# %% [markdown]
# Test the accuracy through human input

# %%
SHEET_DATA = pd.read_excel('data.xlsx', dtype=str)
TEST_LABEL_COUNT = 30

# counters
null_count = 0
right_count = 0
total_count = 0

# get all the columns to look at
_, *attributes = SHEET_DATA.columns

random.seed(100)
for filename in {*random.choices(SHEET_DATA['filename'], k=TEST_LABEL_COUNT)}:
    # get the read values from OCR
    _, *read_vals = SHEET_DATA[SHEET_DATA['filename'] == filename].values[0]

    # show the image and go through each thing
    imshow(cv2.imread(f"{HOME_DIR}/dataset/{filename}"))
    for label, read in zip(attributes, read_vals):

        # add to total no mater what
        total_count += 1

        # add to nulls
        if isinstance(read, float):   # is NaN 
            null_count += 1
            continue

        # check if its right
        true = input(f"Enter the label's {label}: ")
        right_count += true.strip() == read.strip()

    clear_output()

print(f"Accuracy for all features: {right_count/total_count:.2%}")
print(f"Accuracy for only read features: {right_count/(total_count-null_count):.2%}")
# Out:
# Accuracy for all features: 77.33%
# Accuracy for only read features: 94.31%
